# %%
from era5_tool import download_era5_data

# %%
variables = ['vertical_integral_of_eastward_water_vapour_flux', 'vertical_integral_of_northward_water_vapour_flux']
file_directory = r"X:\dewhirst\era5_files"
lat_range = [90, 0]
lon_range = [0, 360]
download_era5_data(2019, 2023, 5, 12, 22, 31, variables, file_directory, lat_range, lon_range, pressure_levels = None)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda\envs\Blocking\lib\site-packages\xarray\backends\file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File ~\anaconda\envs\Blocking\lib\site-packages\xarray\backends\lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('X:\\dewhirst\\era5_files\\era5_vertical_integral_of_eastward_water_vapour_flux_2021_06_08_.nc',), 'a', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), 'dee31406-c709-48eb-815e-dae365ef601d']
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
variables = ['geopotential', 'u_component_of_wind', 'v_component_of_wind']
pressure_levels = [500]
file_directory = "X:\dewhirst\era5_files"
lat_range = [90, 0]
lon_range = [0, 360]
download_era5_data(2016, 2023, 3, 12, 10, 31, variables, file_directory, lat_range, lon_range, pressure_levels)

# %%
import psutil

memory_info = psutil.virtual_memory()
print(f"Total memory: {memory_info.total / (1024 ** 3):.2f} GiB")
print(f"Available memory: {memory_info.available / (1024 ** 3):.2f} GiB")
# Out:
# Total memory: 14.80 GiB
# Available memory: 6.81 GiB
